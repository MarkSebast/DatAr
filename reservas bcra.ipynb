# %%
import matplotlib.pyplot as plt
import pandas
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
colnames = [
            "año", "mes", "e.monetaria", "equivalencia", "u.monetaria or. con act.", "saldos", "promedio mensual"
            ]
dat = pandas.read_csv('reservas bcra.csv', names=colnames, sep=';', thousands=".")

# %%
#Elimno primera fila
data = dat.drop(dat.index[0])

# %%
día = []
tot = 0
while tot != 933:
    día.append(28)
    tot = tot+1
data.insert(2, "día", día)

# %%
data["saldos"] = data["saldos"].str.replace(",","").astype(int)

# %%
print(data.dtypes)
# Out:
# año                         object
# mes                         object
# día                          int64
# e.monetaria                 object
# equivalencia                object
# u.monetaria or. con act.    object
# saldos                       int32
# promedio mensual            object
# dtype: object

# %%
#Convirtiendo meses
data.loc[data['mes'] == 'enero', 'mes'] = 1
data.loc[data['mes'] == 'enero ', 'mes'] = 1
data.loc[data['mes'] == 'febrero', 'mes'] = 2
data.loc[data['mes'] == 'marzo', 'mes'] = 3
data.loc[data['mes'] == 'abril', 'mes'] = 4
data.loc[data['mes'] == 'mayo', 'mes'] = 5
data.loc[data['mes'] == 'junio', 'mes'] = 6
data.loc[data['mes'] == 'julio', 'mes'] = 7
data.loc[data['mes'] == 'agosto', 'mes'] = 8
data.loc[data['mes'] == 'septiembre', 'mes'] = 9
data.loc[data['mes'] == 'octubre', 'mes'] = 10
data.loc[data['mes'] == 'noviembre', 'mes'] = 11
data.loc[data['mes'] == 'diciembre', 'mes'] = 12

# %%
df = data['día'].map(str) + '-' + data['mes'].map(str) + '-' + data['año'].map(str)

# %%
df2 = pandas.concat([df, data], axis=1, sort=False)

# %%
df2.head()
# Out:
#            0   año mes  día e.monetaria equivalencia u.monetaria or. con act.  \
# 1  28-1-1940  1940   1   28        U$S     1.000.000                        1
# 2  28-2-1940  1940   2   28        U$S     1.000.000                        1
# 3  28-3-1940  1940   3   28        U$S     1.000.000                        1
# 4  28-4-1940  1940   4   28        U$S     1.000.000                        1
# 5  28-5-1940  1940   5   28        U$S     1.000.000                        1
#
#    saldos promedio mensual
# 1     493              NaN
# 2     490              NaN
# 3     495              NaN
# 4     495              NaN
# 5     497              NaN

# %%
pandas.to_datetime(df2[0])
# Out:
# 1     1940-01-28
# 2     1940-02-28
# 3     1940-03-28
# 4     1940-04-28
# 5     1940-05-28
#          ...
# 929   2020-04-28
# 930   2020-05-28
# 931   2020-06-28
# 932   2020-07-28
# 933   2020-08-28
# Name: 0, Length: 933, dtype: datetime64[ns]

# %%
df2.rename(columns = {0:'fecha'}, inplace = True)

# %%
df2.tail()
# Out:
#          fecha   año mes  día e.monetaria equivalencia  \
# 929  28-4-2020  2020   4   28        U$S     1.000.000
# 930  28-5-2020  2020   5   28        U$S     1.000.000
# 931  28-6-2020  2020   6   28        U$S     1.000.000
# 932  28-7-2020  2020   7   28        U$S     1.000.000
# 933  28-8-2020  2020   8   28        U$S     1.000.000
#
#     u.monetaria or. con act.  saldos promedio mensual
# 929                        1   43568           43.735
# 930                        1   42589           43.084
# 931                        1   43242           43.051
# 932                        1   43386           43.313
# 933                        1   42842           43.152

# %%
x=df2["fecha"]
y=df2["saldos"]

fig = px.line(df2, x, y,
              title='Reservas BCRA'
             )
fig.update_xaxes(
    rangeslider_visible=True,
)

fig.show()
# Out:
# <div>
#
#
#             <div id="8b0390be-d651-495a-a5d5-1ce99557374c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b0390be-d651-495a-a5d5-1ce99557374c")) {
#                     Plotly.newPlot(
#                         '8b0390be-d651-495a-a5d5-1ce99557374c',
#                         [{"hovertemplate": "fecha=%{x}<br>saldos=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["28-1-1940", "28-2-1940", "28-3-1940", "28-4-1940", "28-5-1940", "28-6-1940", "28-7-1940", "28-8-1940", "28-9-1940", "28-10-1940", "28-11-1940", "28-12-1940", "28-1-1941", "28-2-1941", "28-3-1941", "28-4-1941", "28-5-1941", "28-6-1941", "28-7-1941", "28-8-1941", "28-9-1941", "28-10-1941", "28-11-1941", "28-12-1941", "28-1-1942", "28-2-1942", "28-3-1942", "28-4-1942", "28-5-1942", "28-6-1942", "28-7-1942", "28-8-1942", "28-9-1942", "28-10-1942", "28-11-1942", "28-12-1942", "28-1-1943", "28-2-1943", "28-3-1943", "28-4-1943", "28-5-1943", "28-6-1943", "28-7-1943", "28-8-1943", "28-9-1943", "28-10-1943", "28-11-1943", "28-12-1943", "28-1-1944", "28-2-1944", "28-3-1944", "28-4-1944", "28-5-1944", "28-6-1944", "28-7-1944", "28-8-1944", "28-9-1944", "28-10-1944", "28-11-1944", "28-12-1944", "28-1-1945", "28-2-1945", "28-3-1945", "28-4-1945", "28-5-1945", "28-6-1945", "28-7-1945", "28-8-1945", "28-9-1945", "28-10-1945", "28-11-1945", "28-12-1945", "28-1-1946", "28-2-1946", "28-3-1946", "28-4-1946", "28-5-1946", "28-6-1946", "28-7-1946", "28-8-1946", "28-9-1946", "28-10-1946", "28-11-1946", "28-12-1946", "28-1-1947", "28-2-1947", "28-3-1947", "28-4-1947", "28-5-1947", "28-6-1947", "28-7-1947", "28-8-1947", "28-9-1947", "28-10-1947", "28-11-1947", "28-12-1947", "28-1-1948", "28-2-1948", "28-3-1948", "28-4-1948", "28-5-1948", "28-6-1948", "28-7-1948", "28-8-1948", "28-9-1948", "28-10-1948", "28-11-1948", "28-12-1948", "28-1-1949", "28-2-1949", "28-3-1949", "28-4-1949", "28-5-1949", "28-6-1949", "28-7-1949", "28-8-1949", "28-9-1949", "28-10-1949", "28-11-1949", "28-12-1949", "28-1-1950", "28-2-1950", "28-3-1950", "28-4-1950", "28-5-1950", "28-6-1950", "28-7-1950", "28-8-1950", "28-9-1950", "28-10-1950", "28-11-1950", "28-12-1950", "28-1-1951", "28-2-1951", "28-3-1951", "28-4-1951", "28-5-1951", "28-6-1951", "28-7-1951", "28-8-1951", "28-9-1951", "28-10-1951", "28-11-1951", "28-12-1951", "28-1-1952", "28-2-1952", "28-3-1952", "28-4-1952", "28-5-1952", "28-6-1952", "28-7-1952", "28-8-1952", "28-9-1952", "28-10-1952", "28-11-1952", "28-12-1952", "28-1-1953", "28-2-1953", "28-3-1953", "28-4-1953", "28-5-1953", "28-6-1953", "28-7-1953", "28-8-1953", "28-9-1953", "28-10-1953", "28-11-1953", "28-12-1953", "28-1-1954", "28-2-1954", "28-3-1954", "28-4-1954", "28-5-1954", "28-6-1954", "28-7-1954", "28-8-1954", "28-9-1954", "28-10-1954", "28-11-1954", "28-12-1954", "28-1-1955", "28-2-1955", "28-3-1955", "28-4-1955", "28-5-1955", "28-6-1955", "28-7-1955", "28-8-1955", "28-9-1955", "28-10-1955", "28-11-1955", "28-12-1955", "28-1-1956", "28-2-1956", "28-3-1956", "28-4-1956", "28-5-1956", "28-6-1956", "28-7-1956", "28-8-1956", "28-9-1956", "28-10-1956", "28-11-1956", "28-12-1956", "28-1-1957", "28-2-1957", "28-3-1957", "28-4-1957", "28-5-1957", "28-6-1957", "28-7-1957", "28-8-1957", "28-9-1957", "28-10-1957", "28-11-1957", "28-12-1957", "28-1-1958", "28-2-1958", "28-3-1958", "28-4-1958", "28-5-1958", "28-6-1958", "28-7-1958", "28-8-1958", "28-9-1958", "28-10-1958", "28-11-1958", "28-12-1958", "28-1-1959", "28-2-1959", "28-3-1959", "28-4-1959", "28-5-1959", "28-6-1959", "28-7-1959", "28-8-1959", "28-9-1959", "28-10-1959", "28-11-1959", "28-12-1959", "28-1-1960", "28-2-1960", "28-3-1960", "28-4-1960", "28-5-1960", "28-6-1960", "28-7-1960", "28-8-1960", "28-9-1960", "28-10-1960", "28-11-1960", "28-12-1960", "28-1-1961", "28-2-1961", "28-3-1961", "28-4-1961", "28-5-1961", "28-6-1961", "28-7-1961", "28-8-1961", "28-9-1961", "28-10-1961", "28-11-1961", "28-12-1961", "28-1-1962", "28-2-1962", "28-3-1962", "28-4-1962", "28-5-1962", "28-6-1962", "28-7-1962", "28-8-1962", "28-9-1962", "28-10-1962", "28-11-1962", "28-12-1962", "28-1-1963", "28-2-1963", "28-3-1963", "28-4-1963", "28-5-1963", "28-6-1963", "28-7-1963", "28- ...
